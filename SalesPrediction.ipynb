# %% [markdown]
# <a href="https://colab.research.google.com/github/TanChen168/sales-predictions/blob/main/SalesPrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
df = pd.read_csv('/content/sample_data/sales_predictions.csv')
#df['Outlet_Establishment_Year'].unique()
#df.groupby(['Item_Type']).sum()
df
# Out:
#      Item_Identifier  Item_Weight  ...        Outlet_Type  Item_Outlet_Sales
# 0              FDA15        9.300  ...  Supermarket Type1          3735.1380
# 1              DRC01        5.920  ...  Supermarket Type2           443.4228
# 2              FDN15       17.500  ...  Supermarket Type1          2097.2700
# 3              FDX07       19.200  ...      Grocery Store           732.3800
# 4              NCD19        8.930  ...  Supermarket Type1           994.7052
# ...              ...          ...  ...                ...                ...
# 8518           FDF22        6.865  ...  Supermarket Type1          2778.3834
# 8519           FDS36        8.380  ...  Supermarket Type1           549.2850
# 8520           NCJ29       10.600  ...  Supermarket Type1          1193.1136
# 8521           FDN46        7.210  ...  Supermarket Type2          1845.5976
# 8522           DRG01       14.800  ...  Supermarket Type1           765.6700
#
# [8523 rows x 12 columns]

# %%
# Histogram to view the distributions of various features in your dataset.
# Item weight
plt.style.use('seaborn')
df.loc[:, 'Item_Weight'].hist(bins = 50, edgecolor='black', alpha=0.7)
plt.xticks(rotation = 45)
plt.ticklabel_format(useOffset=False, style='plain')
plt.xlabel('Item Weight')
plt.ylabel('Çount')
#plt.legend(loc='upper right')
plt.show()

# %%
# Item weight
plt.style.use('seaborn')
df.loc[:, 'Item_MRP'].hist(bins = 50, edgecolor='black', alpha=0.7)
plt.xticks(rotation = 45)
plt.ticklabel_format(useOffset=False, style='plain')
plt.xlabel('Item MRP')
plt.ylabel('Çount')
#plt.legend(loc='upper right')
plt.show()

# %%
# Outlet Sales
plt.style.use('seaborn')
df.loc[:, 'Item_Outlet_Sales'].hist(bins = 50, edgecolor='black', alpha=0.7)
plt.xticks(rotation = 45)
plt.ticklabel_format(useOffset=False, style='plain')
plt.xlabel('Item Outlet Sales')
plt.ylabel('Çount')
#plt.legend(loc='upper right')
plt.show()

# %%
# Boxplot to view statistical summaries of various features in your dataset.
LowFatItems = df['Item_Fat_Content'] == 'Low Fat'
RegularFatItems = df['Item_Fat_Content'] == 'Regular'
dfLowFatContent = df.loc[LowFatItems, 'Item_MRP'].values
dfRegularFatContent = df.loc[RegularFatItems, 'Item_MRP'].values
box_props = dict(alpha=0.7)
#dfLowFatContent
#dfRegularFatContent

SnackFoodItems = df['Item_Type'] == 'Snack Food'
dfSnackFood = df.loc[LowFatItems, 'Item_MRP'].values
SoftDrinksItems = df['Item_Type'] == 'Soft Drinks'
dfSoftDrinks = df.loc[LowFatItems, 'Item_MRP'].values

plt.boxplot([dfLowFatContent, dfRegularFatContent, dfSnackFood, dfSoftDrinks], labels=['Low Fat','Regular', 'Snack Food', 'Soft Drinks'], notch=True, widths=0.5, patch_artist=True, boxprops=box_props)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# {'boxes': [<matplotlib.patches.PathPatch at 0x7fc20f9ce650>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fc20f9d7bd0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc20f95ec10>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc20f95e690>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fc20f9d7110>,
# ...
#   <matplotlib.lines.Line2D at 0x7fc20f987b50>]}

# %%
# Heatmap of the correlation between features.

# There is a close correlation between Outlet Sales and MRP as indicated vs. other criteria of the product item

corr = df.corr()
sns.heatmap(corr, cmap = 'Greens', annot = True)
